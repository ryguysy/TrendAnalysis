# %%
import pandas as pd

# %%
df_stock = pd.read_csv('../data/preprocessed_stock_data.csv')  # Load stock data
df_reddit = pd.read_csv('../data/preprocessed_reddit_data.csv')  # Load reddit data

df_stock.head()

model_data = pd.merge(df_stock, df_reddit, on='Date', how='inner')

model_data.head()
# Out:
#          Date        Open        High         Low       Close    Volume  \
# 0  2025-01-07  597.419983  597.750000  586.780029  588.630005  60393100
# 1  2025-01-07  597.419983  597.750000  586.780029  588.630005  60393100
# 2  2025-01-08  588.700012  590.580017  585.200012  589.489990  47304700
# 3  2025-01-08  588.700012  590.580017  585.200012  589.489990  47304700
# 4  2025-01-08  588.700012  590.580017  585.200012  589.489990  47304700
#
#          MA_5       MA_50      MA_200  Movement  Unnamed: 0  \
# 0  589.332007  591.992325  551.879082       0.0          81
# 1  589.332007  591.992325  551.879082       0.0          82
# 2  590.014001  592.240172  552.245492      -1.0          74
# 3  590.014001  592.240172  552.245492      -1.0          75
# 4  590.014001  592.240172  552.245492      -1.0          76
#
#                                              content  upvotes  comments  \
# 0  Hey everyone, any fellow Nana-INTC bagholders ...       74       181
# ...
